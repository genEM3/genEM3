# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
from torch.utils.data import Dataset

# %% [markdown]
# # Dataset

# %%
# Let's look at some data
img = plt.imread('../../data/1.tif')
plt.imshow(img[1:250,1:250], cmap='gray');

# %% [markdown]
# ## Define Dataset subclass
