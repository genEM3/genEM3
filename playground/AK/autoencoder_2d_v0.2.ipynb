# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# # Paths

# %%
data_root = '../data/'
log_root = './logs/'

# %% [markdown]
# # Dataset

# %%
def plotSlice(i):
    plt.figure(figsize=(10,10))
    img = plt.imread(os.path.join(data_root, f'2016-05-26_st015_000303_000_003_000_n_00_crop_{i:03d}.tif'))
    plt.imshow(img, cmap='gray');
    plt.show
# Let's look at some data
import time
for i in range(1,2,1):
    plotSlice(i)
    time.sleep(0.5)

# %%
# Out:
# 2016-05-26_st015_000303_000_003_000_n_00_crop_001.tif

# %%
# Let's get a quick-and-dirty estimate of image summary stats
norm_params = {'mean': np.mean(img), 'std': np.std(img)}
print(np.min(img))
# Out:
# 4684

# %% [markdown]
# ## Define Dataset subclass

# %%
class SBEMCrop2dDataset(Dataset):
    
    def __init__(self, data_root, norm_params):
        self.data_fnames = os.listdir(data_root)
        self.data_root = data_root
        self.norm_params = norm_params
    
    def __len__(self):
        return len(self.data_fnames)
    
    def __getitem__(self, idx):
        img = np.asarray(plt.imread(os.path.join(self.data_root, self.data_fnames[idx])))
        img = self._normalize(img)
        sample = SBEMCrop2dDataset._reshape_to_torch(img)
        return sample
    
    def _normalize(self, img):
        img = (np.asarray(img)-self.norm_params['mean'])/self.norm_params['std']
        return img
    
    @staticmethod
    def _reshape_to_torch(img):
        sample = torch.from_numpy(np.reshape(img, (1, img.shape[0], img.shape[1]))).float()
        return sample

# %% [markdown]
# ## Instantiate dataset subclass

# %%
sbem_dataset = SBEMCrop2dDataset(data_root, norm_params)

# %% [markdown]
# ## Test dataset subclass

# %%
# Show first 3 images in dataset
fig, axs = plt.subplots(1, 3, figsize=(16,12))

for i in range(3):
    sample = sbem_dataset[i]
    img = sample.data.numpy().squeeze()
    axs[i].imshow(img, cmap='gray')
    axs[i].set_title('mean: {:0.3f}, std: {:0.3f}'.format(np.mean(img), np.std(img)))

# %%
img.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Model

# %% [markdown]
# ## Define Model

# %%
def get_conv_pad(input_size, kernel_size, stride):
    padding = np.ceil(((stride-1)*input_size-stride+kernel_size)/2).astype(int)
    return padding

# %%
class Encoder_4(torch.nn.Module):
    
    def __init__(self, input_size, kernel_size, stride, n_fmaps, n_latent):
        super().__init__()
        
        self.input_size = input_size
        self.kernel_size = kernel_size
        self.stride = stride
        self.n_fmaps = n_fmaps
        self.n_latent = n_latent
        
        self.encoding_conv1 = torch.nn.Sequential(
            torch.nn.Conv2d(1, n_fmaps, kernel_size, stride, get_conv_pad(input_size, kernel_size, stride)),
            torch.nn.ReLU())
    
        self.encoding_conv2 = torch.nn.Sequential(
            torch.nn.Conv2d(n_fmaps, n_fmaps*2, kernel_size, stride, get_conv_pad(input_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_conv3 = torch.nn.Sequential(
            torch.nn.Conv2d(n_fmaps*2, n_fmaps*4, kernel_size, stride, get_conv_pad(input_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_conv4 = torch.nn.Sequential(
            torch.nn.Conv2d(n_fmaps*4, n_fmaps*8, kernel_size, stride, get_conv_pad(input_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_fc = torch.nn.Sequential(
            torch.nn.Linear(input_size**2*n_fmaps*8, n_latent),
            torch.nn.ReLU())
        
    def forward(self, x):
        
        x = self.encoding_conv1(x)
        x = self.encoding_conv2(x)
        x = self.encoding_conv3(x)
        x = self.encoding_conv4(x)
        x = self.encoding_fc(x.reshape((-1, 1, self.input_size**2*self.n_fmaps*8)))
        
        return x

# %%
class Encoder_3(torch.nn.Module):
    
    def __init__(self, input_size, kernel_size, stride, n_fmaps, n_latent):
        super().__init__()
        
        self.input_size = input_size
        self.kernel_size = kernel_size
        self.stride = stride
        self.n_fmaps = n_fmaps
        self.n_latent = n_latent
        
        self.encoding_conv1 = torch.nn.Sequential(
            torch.nn.Conv2d(1, n_fmaps, kernel_size, stride, get_conv_pad(input_size, kernel_size, stride)),
            torch.nn.ReLU())
    
        self.encoding_conv2 = torch.nn.Sequential(
            torch.nn.Conv2d(n_fmaps, n_fmaps*2, kernel_size, stride, get_conv_pad(input_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_conv3 = torch.nn.Sequential(
            torch.nn.Conv2d(n_fmaps*2, n_fmaps*4, kernel_size, stride, get_conv_pad(input_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_fc = torch.nn.Sequential(
            torch.nn.Linear(input_size**2*n_fmaps*4, n_latent),
            torch.nn.ReLU())
        
    def forward(self, x):
        
        x = self.encoding_conv1(x)
        x = self.encoding_conv2(x)
        x = self.encoding_conv3(x)
        x = self.encoding_fc(x.reshape((-1, 1, self.input_size**2*self.n_fmaps*4)))
        
        return x

# %%
class Encoder_3_sampling(torch.nn.Module):
    
    def __init__(self, input_size, kernel_size, stride, n_fmaps, n_latent):
        super().__init__()
        
        self.input_size = input_size
        self.kernel_size = kernel_size
        self.stride = stride
        self.n_fmaps = n_fmaps
        self.n_latent = n_latent
        
        self.encoding_conv1 = torch.nn.Sequential(
            torch.nn.Conv2d(1, n_fmaps, kernel_size, stride),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2))
    
        self.encoding_conv2 = torch.nn.Sequential(
            torch.nn.Conv2d(n_fmaps, n_fmaps*2, kernel_size, stride),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2))
        
        self.encoding_conv3 = torch.nn.Sequential(
            torch.nn.Conv2d(n_fmaps*2, n_fmaps*4, kernel_size, stride),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2))
        
        self.encoding_fc = torch.nn.Sequential(
            torch.nn.Linear(36**2*n_fmaps*4, n_latent),
            torch.nn.ReLU())
        
    def forward(self, x):
        
        x = self.encoding_conv1(x)
        x = self.encoding_conv2(x)
        x = self.encoding_conv3(x)
        x = self.encoding_fc(x.reshape((-1, 1, 36**2*n_fmaps*4)))
        
        return x

# %%
class Decoder_4(torch.nn.Module):
    
    def __init__(self, output_size, kernel_size, stride, n_fmaps, n_latent):
        super().__init__()
        
        self.output_size = output_size
        self.kernel_size = kernel_size
        self.stride = stride
        self.n_fmaps = n_fmaps
        self.n_latent = n_latent
        
        self.decoding_fc = torch.nn.Sequential(
            torch.nn.Linear(n_latent, output_size**2*n_fmaps*8),
            torch.nn.ReLU())
        
        self.encoding_convt1 = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(n_fmaps*8, n_fmaps*4, kernel_size, stride, get_conv_pad(output_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_convt2 = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(n_fmaps*4, n_fmaps*2, kernel_size, stride, get_conv_pad(output_size, kernel_size, stride)),
            torch.nn.ReLU())

        self.encoding_convt3 = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(n_fmaps*2, n_fmaps, kernel_size, stride, get_conv_pad(output_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_convt4 = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(n_fmaps, 1, kernel_size, stride, get_conv_pad(output_size, kernel_size, stride)),
            torch.nn.Sigmoid())
        
    def forward(self, x):
        
        x = self.decoding_fc(x)
        x = self.encoding_convt1(x.reshape((-1, n_fmaps*8, self.output_size, self.output_size)))
        x = self.encoding_convt2(x)
        x = self.encoding_convt3(x)
        x = self.encoding_convt4(x)
        
        return x

# %%
class Decoder_3(torch.nn.Module):
    
    def __init__(self, output_size, kernel_size, stride, n_fmaps, n_latent):
        super().__init__()
        
        self.output_size = output_size
        self.kernel_size = kernel_size
        self.stride = stride
        self.n_fmaps = n_fmaps
        self.n_latent = n_latent
        
        self.decoding_fc = torch.nn.Sequential(
            torch.nn.Linear(n_latent, output_size**2*n_fmaps*4),
            torch.nn.ReLU())
        
        self.encoding_convt1 = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(n_fmaps*4, n_fmaps*2, kernel_size, stride, get_conv_pad(output_size, kernel_size, stride)),
            torch.nn.ReLU())

        self.encoding_convt2 = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(n_fmaps*2, n_fmaps, kernel_size, stride, get_conv_pad(output_size, kernel_size, stride)),
            torch.nn.ReLU())
        
        self.encoding_convt3 = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(n_fmaps, 1, kernel_size, stride, get_conv_pad(output_size, kernel_size, stride)),
            torch.nn.Sigmoid())
        
    def forward(self, x):
        
        x = self.decoding_fc(x)
        x = self.encoding_convt1(x.reshape((-1, n_fmaps*4, self.output_size, self.output_size)))
        x = self.encoding_convt2(x)
        x = self.encoding_convt3(x)
        
        return x

# %%
class Decoder_3_sampling(torch.nn.Module):
    
    def __init__(self, output_size, kernel_size, stride, n_fmaps, n_latent):
        super().__init__()
        
        self.output_size = output_size
        self.kernel_size = kernel_size
        self.stride = stride
        self.n_fmaps = n_fmaps
        self.n_latent = n_latent
        
        self.decoding_fc = torch.nn.Sequential(
            torch.nn.Linear(n_latent, 36**2*n_fmaps*4),
            torch.nn.ReLU())
        
        self.encoding_convt1 = torch.nn.Sequential(
            torch.nn.Upsample(scale_factor=2, mode='nearest'),
            torch.nn.ConvTranspose2d(n_fmaps*4, n_fmaps*2, kernel_size, stride),
            torch.nn.ReLU())

        self.encoding_convt2 = torch.nn.Sequential(
            torch.nn.Upsample(scale_factor=2, mode='nearest'),
            torch.nn.ConvTranspose2d(n_fmaps*2, n_fmaps, kernel_size, stride),
            torch.nn.ReLU())
        
        self.encoding_convt3 = torch.nn.Sequential(
            torch.nn.Upsample(scale_factor=2, mode='nearest'),
            torch.nn.ConvTranspose2d(n_fmaps, 1, kernel_size, stride),
            torch.nn.Sigmoid())
        
    def forward(self, x):
        
        x = self.decoding_fc(x)
        x = self.encoding_convt1(x.reshape((-1, n_fmaps*4, 36, 36)))
        x = self.encoding_convt2(x)
        x = self.encoding_convt3(x)
        
        return x

# %%
class AE(torch.nn.Module):
    
    def __init__(self, encoder, decoder):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        
    def forward(self, x):
        
        x = self.encoder(x)
        x = self.decoder(x)
        
        return x

# %% [markdown]
# ## Instantiate Model, Loss and Optimizer

# %%
input_size=302
output_size=input_size
kernel_size=3
stride=1
n_fmaps=4
n_latent=1000
net = AE(
    Encoder_3_sampling(input_size, kernel_size, stride, n_fmaps, n_latent), 
    Decoder_3_sampling(output_size, kernel_size, stride, n_fmaps, n_latent))
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.05, momentum=0.9)

# %% [markdown]
# ## Utility functions

# %%
def data2fig_subplot(inputs, outputs, idx):
    fig, axs = plt.subplots(1, 2, figsize=(16,12))
    img_input = inputs[idx].data.numpy().squeeze()
    axs[0].imshow(img_input, cmap='gray')
    img_output = outputs[idx].data.numpy().squeeze()
    axs[1].imshow(img_output, cmap='gray')
    return fig

# %% [markdown]
# # Train Model

# %%
trainloader = DataLoader(sbem_dataset, batch_size=1, shuffle=False, num_workers=0)
writer = SummaryWriter(log_root)
writer_int = 10
n_epoch = 3
it = 0
for epoch in range(n_epoch):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(trainloader):
        it += 1

#       inputs = trainloader.dataset[0].unsqueeze(0)
        inputs = data
        labels = inputs

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics 
        running_loss += loss.item()
        if i % writer_int == writer_int-1:

            avg_loss = running_loss / writer_int

            print('it: {} (epoch: {}, batch: {}), running loss: {:0.3f}'.format(it, epoch, i+1, avg_loss))

            writer.add_scalar('loss', loss.item(), it)
            writer.add_scalar('avg_loss', avg_loss, it)
            writer.add_figure('inputs', data2fig_subplot(inputs, outputs, 0), it)

            running_loss = 0.0
# Out:
# it: 10 (epoch: 0, batch: 10), running loss: 1.161
# it: 20 (epoch: 0, batch: 20), running loss: 1.156
# it: 30 (epoch: 0, batch: 30), running loss: 1.128
# it: 40 (epoch: 0, batch: 40), running loss: 1.142
# it: 50 (epoch: 0, batch: 50), running loss: 1.126
# it: 60 (epoch: 0, batch: 60), running loss: 1.132
# it: 70 (epoch: 1, batch: 10), running loss: 1.107
# it: 80 (epoch: 1, batch: 20), running loss: 1.133
# it: 90 (epoch: 1, batch: 30), running loss: 1.121
# it: 100 (epoch: 1, batch: 40), running loss: 1.142
# it: 110 (epoch: 1, batch: 50), running loss: 1.125

# %%
# Show input vs output
data2fig_subplot(inputs, outputs, 0)

# %%
plt.hist(inputs[0].data.numpy().squeeze());

# %%
plt.hist(outputs[0].data.numpy().squeeze());
